# %%
import requests as req
from bs4 import BeautifulSoup as bs
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
h = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36"}

# %%
driver = wb.Chrome()

# %%
driver.get('https://www.melon.com/genre/song_list.htm?gnrCode=GN0300#params%5BgnrCode%5D=GN0300&params%5BdtlGnrCode%5D=&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex=1')
result ={}
musicList = []
indexNum = 1

for n in range(1,8) : 
    time.sleep(5)
    url ='https://www.melon.com/genre/song_list.htm?gnrCode=GN0{}00#params%5BgnrCode%5D=GN0{}00&params%5BdtlGnrCode%5D=&params%5BorderBy%5D=POP&params%5BsteadyYn%5D=N&po=pageObj&startIndex=1'.format(n,n)
    driver.get(url)    
    print(n)
    for i in range(1,50):
        driver.get(url)
        time.sleep(1)
        song_Xpath = driver.find_element_by_xpath('/html/body/div/div[3]/div/div/div[5]/form/div/table/tbody/tr[{}]/td[5]/div/div/div[1]/span/a'.format(i))
        song = song_Xpath.text
        print(song)
# Out:
# 1
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_13336/1979341768.py:14: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   song_Xpath = driver.find_element_by_xpath('/html/body/div/div[3]/div/div/div[5]/form/div/table/tbody/tr[{}]/td[5]/div/div/div[1]/span/a'.format(i))
# 그때 그 순간 그대로 (그그그)
# 사랑인가 봐
# 나의 X에게
# 취중고백
# 사랑은 늘 도망가
# 내가 아니라도
# 우리들의 블루스
# 다정히 내 이름을 부르면
# 늦은 밤 헤어지긴 너무 아쉬워
# 듣고 싶을까
# 너의 모든 순간
# 다시 만날 수 있을까
# 고백하는 취한밤에 (Prod. 2soo)
# 바보에게 바보가 (웹툰 '연애의 발견' X 이석훈)
# 팡파레
# 드라마
# 언제나 사랑해
# 해요 (2022)
# 내 손을 잡아
# 바라만 본다
# 모든 날, 모든 순간 (Every day, Every Moment)
# 밤하늘의 별을(2020)
# 눈이 오잖아(Feat.헤이즈)
# 미친 것처럼
# 호랑수월가
# 고백
# 그 하루(feat.반하나)
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 아버지
# With you
# 인생찬가
# 사랑인걸
# I LUV U (with 미란이)
# 서랍
# 이러면 안 될 거 아는데 너 앞에만 서면 나락 (Feat. 10CM)
# 추억은 만남보다 이별에 남아
# 초대
# 너, 너 (N번째 연애 X 휘인 (Whee In))
# 취기를 빌려 (취향저격 그녀 X 산들)
# 어제처럼
# 시든 꽃에 물을 주듯
# 선물
# 너의 번호를 누르고 (Prod. 영화처럼)
# 마지막 너의 인사
# YOU AND I
# 비가 오는 날엔 (2021)
# 밤편지
# 링크
# 사랑의 인사
# 2
# LOVE DIVE
# POP!
# That That (prod. & feat. SUGA of BTS)
# Clink Clink (클링 클링)
# Girls
# FEARLESS
# Feel My Rhythm
# ELEVEN
# INVU
# Next Level
# Dynamite
# I LOVE U
# Weekend
# SMILEY (Feat. BIBI)
# Butter
# Permission to Dance
# 열이올라요 (Heart Burn)
# 도깨비불 (Illusion)
# 롤린 (Rollin')
# 라일락
# Celebrity
# Savage
# Sparkling
# Life′s Too Short (English Ver.)
# Dun Dun Dance
# RUN2U
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# Beatbox
# Step Back
# Darl+ing
# Stay This Way
# Celeb
# Dreams Come True
# 어마어마해
# 러브 쉿!
# 나는 트로트가 싫어요
# Lovesick Girls
# 다시 여기 바닷가
# Dolphin
# DM
# Real Love
# ASAP
# 버퍼링 (Glitch Mode)
# Dance The Night Away
# Queendom
# 비행기
# 상상더하기
# Alcohol-Free
# REALLY REALLY
# 3
# LOVE me
# Yet To Come
# MY BAG
# ZOOM
# 회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 리무진 (Feat. MINO) (Prod. GRAY)
# OHAYO MY NIGHT
# HOT
# 봄날
# 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 문득
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13336/1979341768.py in <module>
#      11     for i in range(1,50):
#      12         driver.get(url)
# ---> 13         time.sleep(1)
#      14         song_Xpath = driver.find_element_by_xpath('/html/body/div/div[3]/div/div/div[5]/form/div/table/tbody/tr[{}]/td[5]/div/div/div[1]/span/a'.format(i))
#      15         song = song_Xpath.text
#
# KeyboardInterrupt:

# %%
result ={}
musicList = []
indexNum = 1


for i in ['봄','여름','가을','겨울']:
     
    indexNum = 1
    search=driver.find_element_by_class_name("ui-autocomplete-input")
    search.send_keys(i)
    search.send_keys(Keys.ENTER)
    for n in range(50) : 
        time.sleep(1)
        
        url = 'https://www.melon.com/search/dj/index.htm?q={}&section=&searchGnbYn=Y&kkoSpl=N&kkoDpType=#params%5Bq%5D=%25EB%25B4%2584&params%5Bsort%5D=weight&params%5Bsection%5D=all&po=pageObj&startIndex={}'.format(i,indexNum)
        driver.get(url)
     
        
        for j in range(1,11):
            time.sleep(1)
            
    
            driver.get(url)
            time.sleep(1)
            btn = driver.find_elements_by_class_name("thumb_frame")[j]
            btn.click()
            songCount_Xpath = driver.find_element_by_xpath('//*[@id="conts"]/div[4]/div[1]/h5/span')
            songCount = int(songCount_Xpath.text[1:-1])
            for k in range(1,10):
                song_Xpath = driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr['+str(k)+']/td[5]/div/div/div[1]/span/a')   
                song = song_Xpath.text
                print(song)    
        indexNum 
 # 곡명을 긁어오는 코드          

        print(songCount)
        
        driver.back()
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_15020/1477448112.py:9: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   search=driver.find_element_by_class_name("ui-autocomplete-input")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_15020/1477448112.py:25: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   btn = driver.find_elements_by_class_name("thumb_frame")[j]
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_15020/1477448112.py:27: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   songCount_Xpath = driver.find_element_by_xpath('//*[@id="conts"]/div[4]/div[1]/h5/span')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_15020/1477448112.py:30: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   song_Xpath = driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr['+str(k)+']/td[5]/div/div/div[1]/span/a')
# 봄이 다시 온다면
# 나도 봄을 좋아할수 있는데
# 봄, 그리고 그대
# Spring Affects Me
# 오월의 어느 봄날 (Feat. 첸(CHEN))
# 봄 안에서
# 봄바람 (Guest 백종명, 김예림)
# 봄 그대 (You're my spring)
# 너는 봄
# 안녕!
# 어느 봄날 (Feat. 쌍미)
# 어느샌가 내 마음에 (웹드라마 '다음곡' OST)
# 홀로솔로 (feat. 지안)
# 옴마 옴마 (feat. 새란, 동후)
# 다시 봄이 (Feat. 김유나)
# 다시, 봄 (Lilac)
# 꽃이 진다고 그대를 잊은 적 없다 (Vocal By 한수연)
# 안녕 (Hi~)
# Toc Toc Toc
# 표현했어
# Walking In The Rain
# 봄날의 기억
# 이쁘다니까
# 운명처럼
# 봄처럼 내게 와
# 봄이 왔네 (Feat. 캡틴락 Of 크라잉넛)
# 사랑하기 좋은 날
# 봄눈
# 첫 데이트
# 벚꽃 엔딩
# 봄 사랑 벚꽃 말고
# 우연히 봄
# 봄날, 벚꽃 그리고 너
# 봄인가 봐 (Spring Love)
# One More Time, One More Chance (초속5센티미터 OST 2007)
# 봄바람 (Feat. 나얼)
# 봄을 그리다
# 봄을 노래하다
# Sunshine
# 봄날에 눈이 부신
# 날씨도 좋은데 (With 임동현)
# 완벽한 봄날 (Feat. 소심한 오빠들)
# 봄이 와
# 봄이 올까요 (Feat. 딘딘)
# 다시, 봄
# 봄이 다시 온다면
# 나도 봄을 좋아할수 있는데
# 봄, 그리고 그대
# Spring Affects Me
# 오월의 어느 봄날 (Feat. 첸(CHEN))
# 봄 안에서
# 봄바람 (Guest 백종명, 김예림)
# 봄 그대 (You're my spring)
# 너는 봄
# 어떤이의 꿈
# 봄비
# 봄의기적
# 봄눈
# 내생에 봄날은...
# 봄 여름 가을..겨울 (Feat. 김태우)
# 봄비
# 봄비 (Acoustic Ver.)
# 봄비
# 봄처럼 내게 와
# 너의 꽃말
# 춘곤 (春困)
# 봄바람
# Sunshine
# 다시, 봄
# 오늘따라 예쁘다
# 일분 일초
# 별, 그대 (The Only Star)
# 봄날의 기억
# 벚꽃 엔딩
# 봄봄봄
# 봄
# 봄의 나라 이야기
# 봄을 그리다
# 복숭아
# 어느 봄날
# 우연히 봄
# 안녕 안녕 안녕
# 그대와 함께
# 들었다 놨다 (Love Actually)
# 사랑에 빠진 딸기 (배스킨라빈스 31 CF 삽입곡)
# 사랑은 은하수 다방에서
# 그대와 나, 설레임 (Feat. 소울맨)
# 벚꽃 엔딩
# illa illa (일라 일라)
# 봄봄봄
# 37
# 봄바람
# 바람이 불어오는 곳
# 봄바람 (Feat. 나얼)
# 결국 봄
# 봄봄봄
# 비타민 (김태희 요정송, 파리바게뜨 CF 삽입곡)
# 봄처럼 내게 와
# 그대네요
# 첫사랑이죠
# 벚꽃 엔딩
# 나만, 봄
# 우린 봄이 오기 전에 (Before Our Spring)
# 봄이 되어준 그대
# 봄바람
# 소나기 (Feat. 10cm)
# 봄봄봄
# 겨울이 봄에게
# 너를 담아 봄 (Feat. 스무살)
# In My Dreams
# Love Song (Feat. 별은)
# 있잖아
# 봄을 닮은 그대
# 같은 말
# 봄의 퍼즐
# 봄이 되어줄게 (Feat. 그_냥)
# Everyday (Album Ver.)
# 사랑이야기
# 우리 사이에도 봄이 왔으면 (Feat. 다인)
# 봄이 온다면 (Drama Ver.)
# 하루 끝
# 연애의 정석 (Feat. TK)
# Lovin' You
# I Need You
# I'm Yours
# 벚꽃이 지면
# 예뻐
# 벚꽃이 지면
# 봄인가 봐 (Spring Love)
# 봄처럼 내게 와
# 봄을 노래하다
# She's A Star
# 데이트 (DATE)
# 봄이 와
# 봄
# 연애의 정석 (Feat. TK)
# My Blossom
# 봄 너를 기다렸어
# 너를 봄
# 봄의 나라 이야기
# 봄바람 (Feat. 나얼)
# 왜 또 봄이야
# 너란 봄 (Feat. 하림)
# 벚꽃 엔딩
# Love Blossom (러브블러썸)
# 봄봄봄
# 당신과 만난 이 날
# 봄냄새
# 꽃송이가
# I Need You
# 비타민 (김태희 요정송, 파리바게뜨 CF 삽입곡)
# 봄날 (How Great Is Your Love)
# 우연히 봄
# 초록 - 언제나 네 곁에
# 낮잠 (Feat. 우희 Of 달샤벳)
# 봄이 왔나 봐
# 봄 (feat. 산다라박)
# 나만, 봄
# 시작됐나, 봄
# First Love
# 벚꽃웨딩
# 봄트랙
# 봄의기적
# 버스
# 너를
# 나 요즘
# 너란 여자, 나란 남자 (Feat. 정환 Of J2M)
# 사랑이 왔어요
# Everyday (Feat. 박현일)
# BABY
# 슈가 캔디
# LOVE SONG
# 봄
# 봄의 세레나데 (Feat. 김수리)
# 꽃핀다
# 나의 봄은
# 잠깐, 봄 (Our Spring)
# 봄꽃
# 우리, 봄날
# 어느새 봄
# 벚꽃잎이 내려앉으며 (Feat. 디어밍)
# 68
# 벚꽃 엔딩
# 썸 (Feat. 릴보이 Of 긱스)
# 봄봄봄
# 개화 (Flowering)
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 말해! 뭐해?
# Blueming
# 우연히 봄
# 폰서트
# Always
# 설렘=기대
# 나의 봄
# 다시 꿈(Spring Day)
# 너를 봄 (I.S.You)
# 꽃구경 가요
# 벚꽃 보러 안 갈래?
# 날아와
# 사랑을 시작하는 봄날에 (with 김대우)
# 노래 불러줘 (Vocal by 수연)
# 다시, 봄이 왔나봐 (Vocal by 수연)
# 첫 데이트
# 꽃송이가
# 두근두근
# Sweet Heart
# 우연히 봄
# Happy Things
# 벚꽃 엔딩
# 나랑 같이 가자(Come With Me)
# 봄날의 기억
# Seoul
# 봄이 온 듯해 (feat.밈(mim))
# 왜 또 봄이야
# 봄바람
# 봄 빛 (The Light)
# 바야흐로 사랑의 계절
# Love blossom (feat. Will Jay, Kelsey Kuan)
# 봄이왔다
# 나비와 고양이 (feat.백현 (BAEKHYUN))
# 노래 불러줘 (Vocal by 수연)
# 봄바람 (Feat. 나얼)
# 노래 불러줘
# 우연히 봄
# 봄이 좋냐??
# 다시, 봄이 왔나봐 (Vocal by 수연)
# 있잖아
# 안겨온다 (Falling In Love)
# 야, 너말야(Hey You) (Feat. 장세민)
# 너를 봄 (I.S.You)
# 보통의 하루
# 봄 그리고 너
# Cashmere (Feat. 네이비쿼카)
# Universe
# 상냥함의 용기
# 라일락
# 공항에서
# Warm
# 다시, 봄
# Callin'
# 눈사람
# 봄이 피어나
# 러브레터
# 잊을 수 있을까
# 안부 (letter)
# 나만, 봄
# 봄이 좋냐??
# 봄 사랑 벚꽃 말고
# 봄봄봄
# Blueming
# 우연히 봄 (2021)
# 벚꽃 엔딩
# 봄이 오는 날에
# 내게도 봄
# 벚꽃 엔딩
# 우연히 봄
# 봄 사랑 벚꽃 말고
# Madeleine Love
# 꽃송이가
# 나만, 봄
# Whatever You Do (Feat. Gray)
# 썸 (Feat. 릴보이 Of 긱스)
# Me You (Feat. 백예린 Of 15&)
# 봄의 찬가 (맥심 모카골드 CF, tvN 꽃보다 할배 삽입곡)
# 간지러운 4월의 햇살
# 바람의 왈츠
# 봄날의 기억
# 시간이 멈추는 봄
# 점점 여리게 마음, 가장 여린곳에
# Leaf Song
# Brahms : Waltz No.15 In A Flat Major Op.39 (브람스 : 왈츠 15번 내림 가장조 작품번호 39)
# 사랑의 인사
# 80
# 봄이 오는 소리 (Feat. 계피)
# 다시, 봄
# 민들레 (full ver.)
# 살며시 봄이 오면
# 봄 빛 (The Light)
# 봄바람 (Spring Breeze)
# 봄이 되어줄게 (prod.공기남)
# 봄비
# 봄 안녕 봄
# 봄
# 입춘
# Spring I Love You Best
# 봄길
# 개화
# 새 춤
# 봄날의 봄
# 봄의 후유증
# 봄이 오면
# 꿀맛
# 봄
# 달타령
# 봄
# 겨울의 끝
# 코끝에 겨울
# 꽃구경
# 그날에 우리
# 봄을 그리다
# 봄날
# 연애시대 (Feat. Ra.D) (Narr. 한효주)
# 봄
# 봄의 나라 이야기
# 첫사랑
# 연애하나 봐
# 우린 봄이 오기 전에 (Before Our Spring)
# 봄이왔다
# 왜 또 봄이야
# LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 겨울에서 봄
# 무지개 (Feat. 윤닭 Of 오브로젝트)
# Say Yes
# My Blossom
# 안녕 (Hi~)
# Blueming
# 봄날
# 완벽한 봄날 (Feat. 소심한 오빠들)
# 꽃
# 우연히 봄
# 바람 (Wind)
# Orange
# 봄
# 빛 (The Light)
# 꽃 (Flower)
# FLOWER (Korean Ver.)
# FLOWER SHOWER
# Everlasting Sunset
# 봄에게 바라는 것
# 벚꽃 엔딩
# VIVA청춘
# 유후 (You, Who?)
# 봄 사랑 벚꽃 말고
# 우연히 봄
# 나만, 봄
# 봄봄봄
# 10분 전
# Fall in Love
# 옴마 옴마 (feat. 새란, 동후)
# 라일락
# 어느 봄날 (Feat. 쌍미)
# GANADARA (Feat. 아이유)
# 썸 타긴 뭘 타
# 이렇게 좋아해 본 적이 없어요
# LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 벚꽃 엔딩
# 나만, 봄
# 봄날 (How Great Is Your Love)
# 파란 봄
# 봄
# 봄바람
# 하루 끝
# 오늘도 난 봄을 기다려
# 너란 봄 (Feat. 하림)
# 봄날은 간다
# 봄이 오면
# 봄 처녀
# 봄 여름 가을 겨울
# 봄비
# 봄
# 봄이 오면
# 봄처녀 오셨네
# 봄의 신앙 (Fru Hling Sglaube)
# 15
# Airplane
# 햇살
# 니 맘 내 맘(EYE TO EYE)
# 우연히 봄
# 옴마 옴마 (feat. 새란, 동후)
# 살짝 설렜어 (Nonstop)
# 나만, 봄
# FANCY
# 봄 (feat. 산다라박)
# 4년전 5월 그때의 우리
# 민들레 (full ver.)
# 목련 필 무렵
# 봄 안녕 봄
# 봄
# 5월의 당신은
# 얼마나 더
# 네가 좋아 (Vocal 이민혁)
# 너는 어떻게 (Feat. 백예린)
# 오지 않을 것 같던 계절
# 꽃 (Prod. 정키)
# 봄의 발라드 (With NILE(나일))
# 오늘의 기분
# 인생 봄날 (Beautiful Mint Life)
# 이번 봄이 가기 전까지
# 5월의 당신은
# 봄바람
# 봄이 오면
# 썸 타긴 뭘 타
# 3월 같은 너
# 안아줘
# 10분 전
# 이렇게 좋아해 본 적이 없어요
# LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# Stage
# 그렇게, 봄
# Surprise (원곡 웹드라마 'Luv Express' OST)
# 그날의 봄
# 꿈
# 뭔가 잘못됐어
# 봄이 사라지면
# 꽃
# Help
# 봄은 겨울이 꾸는 꿈
# Credits
# RAINBOW
# 꽃향기가 날 때쯤에
# 봄맞이 가출
# Will Be 봄
# 벚꽃 엔딩
# 밤벚꽃
# 벚꽃, 밤
# 봄날의 소나기 (Paper Umbrella)
# 봄이 온 것 같애
# 토요일 오후에
# 봄인가 봐 (Spring Love)
# 보통연애 (Feat. 박보람)
# 야 하고 싶어 (Feat. 시우민 of EXO)
# 이쁘다니까
# 꿀맛
# 벚꽃 엔딩
# 우연히 봄
# 연예할래
# 너란 봄 (Feat. 하림)
# 벚꽃이 내린다
# 봄날의 기억
# Killing Me
# 봄바람 (Feat. 나얼)
# 어느 봄날
# 사월이 지나면 우리 헤어져요 (Beautiful goodbye)
# 오월의 어느 봄날 (Feat. 첸(CHEN))
# 봄
# 봄은 있었다
# 왜 또 봄이야
# 꿀맛
# 봄 사랑 벚꽃 말고
# 하늘바라기 (Feat. 하림)
# 사월이 지나면 우리 헤어져요 (Beautiful goodbye)
# Bubble Love
# 선 (Feat. 우효) (45.7cm)
# 처음 뵙겠습니다 (With 휘성)
# 봄의 나라 이야기
# 다시, 겨울이 지나고 봄이 오듯이 (feat. 신예영)
# 어느 봄날
# 봄을 그리다
# 꽃피는 봄이오면
# 오늘도 그대만 (Feat. 정동원)
# 흰 눈이 녹아 다른 봄이 와도
# 다시 봄이 (Feat. 김유나)
# 어느 봄날의 이별
# 그렇게 (With. 이설아)
# 30
# 봄
# 눈을 감아
# 제목 없는 곡
# A Door
# 기도
# 우리 이렇게 헤어지기로 해
# 첫사랑
# 새겨울 (Remixed)
# 나
# Fix You
# 봄이왔다
# 정말 고마워서 만든 노래
# 오늘
# 상록수 2020
# 슈퍼스타 (함께부르기)
# 슈퍼히어로 (영화 엑시트 삽입곡)
# Shine A Light (Flight Facilities Remix)
# 잘 지내니? (Vocal by Anna)
# 벚꽃 엔딩
# 꿀맛
# 어느 봄날
# I Love You
# 봄이 와 (Feat. 롤러코스터)
# 카드캡터체리
# 사랑하니까
# 봄인가 봐 (Spring Love)
# 벚꽃이 내린다
# 봄봄봄
# 꿀맛
# 처녀총각
# 봄이 오는 길
# 꽃길
# 봄이 오면
# 그댄 봄비를 무척 좋아하나요
# 봄
# 봄비
# 같이 걷는 길
# Whatever Love
# 달리기
# Orange
# Sendai
# 다시, 봄
# 너와 나
# Love Is A Song
# 꽃길 (Prod. By ZICO)
# 3月 (Feat. 조규찬)
# 봄날, 벚꽃 그리고 너
# 꿀맛
# 예감 좋은 날
# 프리지아
# 봄이여 오라 (Feat. 유리)
# 연애하나 봐
# 쏘쏘
# 봄바람 (Feat. 나얼)
# 봄날
# 첫 눈
# 꿀맛
# 봄이 좋냐??
# 첫눈처럼 너에게 가겠다
# 어머니의 된장국 (Feat. Ra.D)
# 레시피
# 아메리카노
# Chocolate (초콜릿)
# 나들이 갈까
# 꿀맛
# 봄을 노래하다
# 벚꽃, 밤
# 썸 (Feat. 릴보이 Of 긱스)
# 벚꽃 엔딩
# 좋다고 말해
# 쿵쿵쿵
# 봄이 오는 날에
# 너=봄
# 오늘만 놀아요
# 외국인의 고백
# 안녕 (Hi~)
# Take It Slow
# Je T'aime
# Take Out
# 사랑이란 말이 어울리는 사람(사말어사)
# 꽃잎점
# 하늘바라기 (Feat. 하림)
# Mr. Chu (On Stage)
# 봄은 있었다
# 쿵쿵쿵
# 햇살은 따뜻해
# 질투가 좋아
# 너란 봄 (Feat. 하림)
# 봄
# I Need You
# 88
# 봄날의 기억
# 날씨가 미쳤어
# 봄이왔다
# 처음부터 너와 나
# 첫사랑의 멜로디
# 설렘주의
# VIVA청춘
# 봄바람
# 벚꽃이 지면
# 그대와 나, 설레임 (Feat. 소울맨)
# 꽃송이가
# Dream (Prod. by 박근태)
# 질투가 좋아
# SoulMate (Feat. 아이유)
# Starlight (Feat. DEAN)
# 한 발짝 두 발짝
# 이쁘다니까
# 꽃길 (Prod. By ZICO)
# 햇살이 아파 (With 한소현 Of 3rd Coast)
# 사랑은 어디로 간 걸까
# 다시, 봄
# 어느 봄날에 (Vocal by 박연 of 담소네공방)
# 봄
# 후회
# 없구나
# 봄의 발라드 (With NILE(나일))
# 봄이 좋냐??
# 어느 봄날 (Feat. 쌍미)
# 다시, 봄
# 겨울에서 봄
# 유채꽃
# I Feel You
# 사랑이 뭔데
# Say Yes
# 사랑 빛
# 바람이 부네요
# 그 전화 받지 마 (Please)
# 봄인가 봐 (Spring Love)
# 나만, 봄
# 우연히 봄
# Perhaps Love (사랑인가요) (Prod.By 박근태)
# 벚꽃 엔딩
# 사계 (Four Seasons)
# 봄이 와
# 덕수궁 돌담길의 봄 (Feat. 10cm)
# 봄봄봄
# 나만, 봄
# 벚꽃 엔딩
# 바람
# 주저하는 연인들을 위해
# 고백
# Dancing Queen (From 'Mamma Mia!' Original Motion Picture Soundtrack)
# Shinjuku Twilight
# 우주를 줄게
# 다시, 봄
# 봄
# 수목원에서
# 산책
# Drunken Shrimp
# Lullaby For A Cat
# 별 탓
# 오늘 서울은 하루종일 맑음 (Vocal 윤하)
# 봄 사랑 벚꽃 말고
# Killing Me
# 홀로봄
# 봄
# 다시, 봄
# 봄을 그리다
# 야생화
# 나란 책 (Read Me) (Feat. PUNCHNELLO)
# 새 신발 (I Wander) (Feat. 개코)
# Butterfly
# Love Blossom (러브블러썸)
# 봄날의 기억
# 나만, 봄
# 나들이 갈까
# 사랑에 빠졌죠 (당신만이)
# 봄비
# 벚꽃 엔딩
# 예쁘다
# Would U
# 주저하는 연인들을 위해
# 너라는 세상
# She (Hidden Track No.V 1월 선정곡)
# Who Are You (Feat. 개코)
# I'll find you (Feat. June)
# 봄
# Mine (Feat. Chawoo, Choyoung)
# Switch
# 봄이 되어줄게 (Feat. 그_냥)
# 16
# 벚꽃 엔딩
# 봄이 오는 날에
# 벚꽃송
# 봄날의 기억
# 햇살이 아파 (With 한소현 Of 3rd Coast)
# 첫사랑
# 너에게 못했던 내 마지막 말은
# 봄은 있었다
# 처음이라서
# Pink!
# 봄 그리고 너
# Nerdy Love (Feat. 백예린)
# Square (2017)
# 봄바람 (Feat. 나얼)
# 너를 좋아하니까
# 봄처럼 내게 와
# 봄 사랑 벚꽃 말고
# 여행일기
# 연애소설 (Feat. 아이유)
# 썸 탈꺼야
# 꽃 길
# 봄인가 봐 (Spring Love)
# 봄봄봄
# 봄이왔다
# 봄의 판타지
# 봄처녀
# My Blossom
# 네 옆에 있으면
# 너의 향기
# Color Of My Life
# Oh! Spring
# 봄 안에서
# 이렇게 좋아도 되니
# 부등부등 (Feat. 권기연)
# DM (매일이 선물)
# 손금
# 봄날의 기억
# 봄은 있었다
# 봄날의 기억 (Spring Memories)
# 봄이 오나요
# 벚꽃 보러가자
# 봄 너를 기다렸어
# 봄을 닮은 그대에게 (Sunshine)
# 벚꽃이 내려 앉은 길
# 벚꽃샤워 (Feat. 김메리 Of 메리스윗카페)
# 무지개 (Feat. 윤닭 Of 오브로젝트)
# 2cm (Feat. 폴킴)
# 사랑은 은하수 다방에서
# 안녕, 봄
# 걷자, 집앞이야 (Feat. 주예인)
# 화가 (Feat. 와인 (Wyne))
# 사랑이 찾아오나 봐
# 널 향해 피어나
# 너를 보여줘
# One Dream One Korea (Original Ver.)
# come out and play
# Storm Song (LG오브제 광고배경음악)
# 외로움의 시작
# I Will
# 또 하루
# love is everything
# 미소를 보여줘 (Acoustic Ver.)
# 그리고 별
# 봄이 왔나 봐
# 봄을 닮은 너는
# Cherry Blossom
# 비밀
# 달달해 (Acc Ver.)
# 봄이 오는 소리
# 봄의 한가운데
# 햇살 좋은 어느 봄날에
# 봄이 싫은 이유
# Lovefool
# Altogether Alone
# The Simple Things
# Picnic
# Happy (Gru's Theme From Despicable Me 2)
# Romeo N Juliet (알렉스, 신애 듀엣 원곡) (우리결혼했어요 삽입곡)
# 왜 또 봄이야
# Beautiful Day
# 좋다
# 오묘해
# 달콤한 빈말 (Feat. 바버렛츠)
# 구름
# 나는 볼 수 없던 이야기
# I pray
# 레인보우 (Rainbow)
# 그대만 떠올라
# 사랑이 뭔데
# 밤, 바다, 여행
# 107
# True Romance (엔딩 테마)
# 봄이 좋냐??
# 봄비 (Spring Rain)
# 봄,
# 왜 또 봄이야
# 우연히 봄
# 봄 사랑 벚꽃 말고
# 봄봄봄
# 봄인가 봐 (Spring Love)
# 꽃 길
# 봄날
# 로맨틱하게
# 별 바람 꽃 태양
# Love Blossom (러브블러썸)
# 꽃길만 걷게 해줄게
# 봄봄봄
# Perfect Day
# So Nice (GMF 2016 Ver.) (Feat. 권정열, 김민석, 달총, 빌리어코스티, 안녕하신가영, 이원석, 이한철, 페퍼톤스)
# 파핑파핑 바나나 (베스킨라빈스 31 CF 삽입곡)
# Flat Shoes (Feat. Lovey)
# Give It 2 U
# 넌 나 어때
# 소풍
# 봄 스윙
# Mellow song (Duet 홍재목)
# 설레나봄
# My Blossom
# 그런 연애 (Feat. 아인 of 모모랜드)
# 우연히 봄 (Acoustic Ver.)
# 봄날의 기억 (Spring Memories)
# 봄바람
# 덕수궁 돌담길의 봄 (Feat. 10cm)
# 너의 귓가에 안녕
# Agit
# 봄비
# 겨울에서 봄
# 봄이 온다고
# 햇살은 따뜻해
# 다음이 있을까
# 공원에서
# Ribbon In The Sky (1982 Musiquarium Ver.)
# 바람기억
# 꽃피는 봄이오면
# 바람, 어디에서 부는지
# Mornin'
# 봄이 좋냐??
# 우연히 봄
# 벚꽃 엔딩
# 봄 사랑 벚꽃 말고
# 봄봄봄
# 봄인가 봐 (Spring Love)
# 너는 나의 봄이다
# Love Blossom (러브블러썸)
# 너란 봄 (Feat. 하림)
# 꽃송이가
# 팔레트 (Feat. G-DRAGON)
# 봄처녀
# 벚꽃 엔딩
# 우연히 봄
# 카드캡터체리
# 꽃 길
# Love Blossom (러브블러썸)
# 봄 사랑 벚꽃 말고
# 봄봄봄
# 벚꽃 엔딩
# 꽃송이가
# 처음엔 사랑이란게
# 여수 밤바다
# 동경소녀
# 네온사인
# 봄
# 봄
# Feeling
# 피앙세 (fiancée) (Feat. Microdot)
# 그럴 수밖에
# 오래된 노래
# 하고 싶은 말 (Feat. 한올)
# 고백
# 고백
# I'm In Love (Piano RMX)
# 왜 이제야 왔니
# 오늘따라 예쁘다
# 어느새 봄 (Vocal 변흥수)
# 썸 (Feat. 릴보이 Of 긱스)
# 유채꽃
# 라일락
# 손을 잡는다거나, 같이 걷는다거나
# I Can't Live Without You
# 봄 안녕 봄
# Everyday (Album Ver.)
# 61
# Hey Jude (헤이 주드 : 영화 '프라하의 봄')
# 봄이 오는 소리
# 좋은 날
# 다시 돌아, 봄
# 봄
# 꽃
# 고향의 봄
# 봄처녀
# 봄이 오는 길
# 봄이라서 그래
# 봄날의 소나기 (Paper Umbrella)
# 데이트
# Tell Me
# Beautiful Day
# 유후 (You, Who?)
# 봄냄새
# 봄노래
# 하늘바라기 (Feat. 하림)
# 다시, 봄
# 봄봄봄
# 다시, 봄
# 봄이 되어줄게 (Feat. 그_냥)
# 봄
# 고백해요
# 봄날은 간다
# 봄이 되어준 그대
# 겨울에서 봄
# 녹는다
# 요리 좀 해요 (Cook for love)
# 사랑만들기
# 니가 하면 로맨스 (Feat. 다비치)
# 오늘부터 1일 (Day 1)
# 화창한 날에 (A Bright Day)
# 썸남썸녀 (Feat. 휘성)
# Marry You
# 나가면 고생이야 (Feat. Beenzino) (Come To My Crib)
# Falling
# 봄이 오면
# 봄이라서 그래
# 봄이라서 발매함
# 너란 봄 (Feat. 하림)
# 사랑이 뭔데
# 너랑, 봄 (Feat. 재희 Of 어쿠루브)
# 어느새 봄 (Vocal 변흥수)
# 봄이 와 (Feat. 롤러코스터)
# 봄이 온다면
# 봄처럼 내게 와
# 봄눈
# 봄이 되어줄게 (Feat. 그_냥)
# 벚꽃비행
# 봄은 그래
# 완벽한 봄날 (Feat. 소심한 오빠들)
# 너를 좋아하나 봄
# 닮은거래요
# 벚꽃 팝콘 (Lovely Days) (Feat. 서영 Of 헬로비너스)
# My Blossom
# More Than Words
# 너란 봄 (Feat. 하림)
# 우연히 봄
# 꽃, 그리고 너 (Feat. 김꽃)
# 떨려 죽겠어 (Feat. 구인회 Of 프리티브라운, 온리유)
# 그대로 봄 (Feat. 후아유)
# 나만, 봄
# 커피 한 잔 할래요
# 나와 (With Me)
# 나에게 넌
# 너를 담아 봄 (Feat. 스무살)
# 나의 봄 (Feat. CHEEZE)
# 봄봄봄이 와요 (Feat. 로코)
# 하늘바라기 (Feat. 하림)
# 사랑은 바람처럼
# 어떤가요
# 니가 좋아
# 너를 사랑해
# 사랑의 마음 가득히
# 좋아 좋아
# 그렇게 너를 사랑해 (전지현 CF삽입곡)
# LOVE (with Young K of DAY6)
# 아로하
# 별똥별
# 아로하
# 움트네, 봄
# 미지근하게
# 봄이 오면
# 봄 너를 기다렸어
# Beautiful Day
# 하늘바라기 (Feat. 하림)
# 사랑에 빠진 나
# 봄냄새
# 카페에 앉아
# 36
# 아침 점심 저녁 (Feat. 태연 Of she'z) (Korean Ver.)
# Butter Beer (Feat. Ari:L, PIVOT)
# 벚꽃 날린다 (Cherry Blossoms Falling)
# 오늘 취하면 (Feat. 창모) (Prod. SUGA)
# 네 생각 나더라
# Oh Beautiful
# Love Again
# Marry Me
# 쓰담쓰담
# 봄 사랑 벚꽃 말고
# 봄봄봄
# 봄이 좋냐??
# 봄인가 봐 (Spring Love)
# 봄바람
# 봄을 그리다
# 봄 타나봐 (BOMTANABA)
# 봄이 와
# 하루 끝
# 왜 또 봄이야
# 봄바람
# 봄
# Spring (봄)
# 미남 (미래남친) (Feat. 여자친구 예린)
# Love Blossom (러브블러썸)
# Spring
# 봄비
# 벚꽃
# Right (Feat. SOLE)
# 봄봄
# 나의 봄 (Feat. CHEEZE)
# 있잖아
# 살랑
# Nerdy Love (Feat. 백예린)
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 봄이 올까요
# 나들이 갈까
# 봄 안녕 봄
# 첫사랑
# 366일
# 봄은 있었다
# 처음이라서
# 처음 느껴본 이별 (Feat. 곽진언)
# 너에게 못했던 내 마지막 말은
# 햇살이 아파 (With 한소현 Of 3rd Coast)
# 앓이 (With Windy)
# 봄봄
# #첫사랑
# 무지개 (Feat. 윤닭 Of 오브로젝트)
# Love Blossom (러브블러썸)
# 사랑 빛
# 이쁘다니까
# 내 눈에만 보여
# Everytime
# 덕수궁 돌담길의 봄 (Feat. 10cm)
# 벚꽃 엔딩
# 봄 사랑 벚꽃 말고
# 너란 봄 (Feat. 하림)
# 나만, 봄
# 봄이 좋냐??
# 벚꽃이 지면
# 봄은 있었다
# 봄날의 기억
# 봄봄봄
# 벚꽃 엔딩
# 봄 사랑 벚꽃 말고
# 봄이 좋냐??
# 처음엔 사랑이란게
# 사랑은 은하수 다방에서
# 봄봄봄
# 프리지아
# 오늘부터 1일 (Day 1)
# 마음
# 봄이 와 (Feat. 롤러코스터)
# 봄을 닮은 너는
# 봄
# 좋아하는 마음
# 봄의기적
# 봄인가 봐 (Spring Love)
# 봄
# 봄을 그리다
# 사랑... 겨울에 부르는 애절한 봄의 노래 (Original Ver.)
# Together
# 봄맞이
# 꽃
# 그때가 좋았다 하네
# 비가 내리네
# 꽃 파는 처녀
# 꽃 (Feat. 하은)
# Table Talk
# 바람, 노래
# 44
# 빗소리
# My Spring
# 흘러 (Feat. 지성)
# 봄 사랑 벚꽃 말고
# 봄봄봄
# 봄이 좋냐??
# 봄의 나라 이야기
# 봄비
# 꽃피는 봄이오면
# 연애상담인듯
# 볼매
# 묘해, 너와
# 요즘 너 말야
# 봄이왔다
# 어느 봄날
# 랄랄라, It's Love!
# 봄바람 (Feat. 나얼)
# 산들산들
# 평대의 봄
# 세상 밖으로
# 봄이 오면 (Feat. 김윤주 Of 옥상달빛)
# 꽃나무 아래에서
# 푸른봄 靑春 (Feat. 나희경)
# 봄봄
# 봄눈
# 봄이 오면 (Guitar ver.)
# 얘, 앞산에 꽃이 피면
# Lucky Day
# 숙녀예찬
# Happy Things
# 좋아
# 어떤날
# Love Supreme
# 끝나지않은노래
# Do I Need A Reason
# 봄
# 비 개인 후 비 (Feat. 키디비)
# 무지개 (Feat. 윤닭 Of 오브로젝트)
# Walkin' In The Rain
# Toy
# Brunch
# Everytime
# 처음엔 사랑이란게
# 최고의 행운
# 몰라요
# You're So Lovely
# 봄바람에 흩날리는 저 벚꽃잎처럼
# 봄봄
# One Day
# 안녕, 따스한 봄
# 잘 지내니?
# 불쑥, 봄
# 봄은 소리없이 온다
# 긴 여행을 떠나는 이에게
# 봄봄봄
# 봄 사랑 벚꽃 말고
# 우연히 봄
# 봄바람
# 봄을 그리다
# 봄이 와
# 다시, 봄
# 봄 타나봐 (BOMTANABA)
# 봄바람 (Feat. 나얼)
# 봄날의 기억
# So Pretty
# Killing Me
# 그려본다 (내가 그린 그림)
# 너 같아서
# 두 번째 고백
# 썸 (Feat. 릴보이 Of 긱스)
# 틈
# 봄 사랑 벚꽃 말고
# Day 1
# 너 때문에
# 너 땜에 못살아 (Feat. 버벌진트)
# Wish
# 뭐 어때 (Feat. 크루셜스타) (Whatever)
# 야 하고 싶어 (Feat. 시우민 of EXO)
# 벚꽃잎(Spring in me) (Duet. 달총 of CHEEZE)
# 내 입술 따뜻한 커피처럼 (Feat. 이성경) (Prod. by 박근태)
# 하늘바라기 (Feat. 하림)
# Flat Shoes (Feat. Lovey)
# 뭘해도 예쁜걸
# 오늘밤 뭐해?
# 사랑한대 (With Windy)
# Hawaian couple (에뛰드 복숭아송 원곡)
# 넌 그날 (Feat. 유인나)
# 그날에 우리
# 요즘 너 말야
# 고백
# 36
# 봄의기적
# 나 그대라는 봄에 누워
# 너, 나, 봄
# 봄아
# 결국 봄
# 봄날, 벚꽃 그리고 너
# 겨울이 봄에게
# 겨울이 지나고 봄이 오듯이
# 봄비
# Sugar
# 고백
# 거북이
# 젊은날
# SUNSHINE
# Sunshine (Feat. 소야)
# Me You (Feat. 백예린 Of 15&)
# Ma Boy 2 (Feat. 효린)
# Always
# 봄날의 기억
# VIVA청춘
# 널 생각해
# 200%
# 좋다
# 벚꽃 엔딩
# 우연히 봄
# Love Blossom (러브블러썸)
# Madeleine Love
# 그대와 나, 설레임 (Feat. 소울맨)
# Lay Back
# 봄날에 눈이 부신
# Bike
# Crush (Reprise)
# 봄봄봄
# 꽃 처럼 한 철만 사랑해 줄 건가요?
# Vivid
# 안아줘요
# Bike
# Crush (Reprise)
# 꽃 처럼 한 철만 사랑해 줄 건가요?
# Vivid
# 안아줘요
# 사랑한다는 말
# 그대와 함께
# Twosome
# 가끔 네 생각이 나는 걸
# 봄이 좋냐??
# 봄날의 기억
# 봄
# 하늘 아래서
# 심쿵주의보
# 봄날의 기억 (Spring Memories)
# Love Blossom (러브블러썸)
# 봄바람
# I am Love (Feat. 요조)
# 벚꽃 엔딩
# 우연히 봄
# 묘해, 너와
# 봄 사랑 벚꽃 말고
# 여자사람 친구
# 당신과는 천천히
# 봄날, 벚꽃 그리고 너
# 사실은
# 좋다
# 너의 의미 (Feat. 김창완)
# 어느 봄날
# 벚꽃 엔딩
# Love Blossom (러브블러썸)
# 우연히 봄
# 봄 사랑 벚꽃 말고
# 봄봄봄
# 썸 (Feat. 릴보이 Of 긱스)
# 하루 끝
# 봄이 왔어요
# 너.로.길 (너에게로 가는 길)
# 좋아, 고마워 (맥심 화이트골드 - 김연아편 CF 삽입곡)
# 봄의 향기
# 나의 봄이 되어줘
# 꽃샘추위
# 봄이 온 듯해
# 너를 담아 봄 (Feat. 스무살)
# 바람이 부네요
# 톡톡
# Sunday Morning
# 겨울에서 봄
# 다시, 봄
# ILYSB (Stripped)
# UGH!
# 고백
# 하늘바라기 (Feat. 하림)
# Thinkin Bout You (Spring Sampler / 2012)
# 80
# 봄날에 눈이 부신
# 봄날, 벚꽃 그리고 너
# 예뻐 (Feat. 리제)
# 우연히 봄
# 그쪽
# 산들산들
# 미치게 섹시해 (Feat. 키디)
# Love Blossom (러브블러썸)
# 감자꽃
# 봄이 좋냐??
# 벚꽃 엔딩
# 꽃송이가
# 봄 사랑 벚꽃 말고
# 봄봄봄
# 우연히 봄
# 우연히 봄 (Acoustic Ver.)
# 봄, 추억
# 봄인가 봐 (Spring Love)
# 벚꽃 엔딩
# 꽃송이가
# 봄바람
# 봄봄봄
# Love Love Love
# 우연히 봄
# 봄 사랑 벚꽃 말고
# 봄을 그리다
# 봄이 와
# 우연히 봄
# 벚꽃 엔딩
# 봄봄봄
# 꽃송이가
# 봄날
# 봄 사랑 벚꽃 말고
# 너의 손 잡고
# 벚꽃이 지면
# 하늘바라기 (Feat. 하림)
# 200%
# 봄 사랑 벚꽃 말고
# 봄날은 간다
# Love Blossom (러브블러썸)
# 데이트
# 봄이 와 (Feat. 롤러코스터)
# 바야흐로 사랑의 계절
# 조금씩, 천천히, 너에게
# 산책
# A ('collapsedone' Remix)
# Beautiful
# Love, LaLaLa
# 고백하기 좋은 날
# 말하고 싶은 게 있어
# 봄 타나봐 (BOMTANABA)
# 사랑하고 싶어요
# 살빼지 마요
# 소년, 소녀 (With 토마스쿡)
# 벚꽃 엔딩
# Love Blossom (러브블러썸)
# 200%
# 꽃송이가
# 유후 (You, Who?)
# 봄인가 봐 (Spring Love)
# 봄이왔다
# 봄날의 기억
# 그대 입술이 (With 채지연 - 풋풋)
# 봄날 크리스마스 (Guitar.정성하)
# 내(가) 너(를)
# 다 핀 꽃
# 예쁜하루
# 이런게 행복이라면
# 좋아해
# Mine (Feat. Chawoo, Choyoung)
# 인사
# 너에게 간다
# 계절의 끝에서
# 밤의 연인들
# 선인장 (Duet)
# 우리 처음 만난 날
# 이보다 좋을 순 없다.
# 청춘 (For 영화 족구왕)
# 춤추는 봄
# VIVA청춘
# Man In Love (남자가 사랑할때)
# 봄이왔다
# 봄이 와 (Feat. 롤러코스터)
# 지금은 겨울이지만 곧 봄이 올 것 같아
# 너=봄
# 봄이니까
# 봄처럼
# 봄바람
# 꽃피는 봄이오면
# 봄비 (With 알리)
# 15
# 우연히 봄
# 봄 사랑 벚꽃 말고
# 봄이 좋냐??
# 나만, 봄
# 봄인가 봐 (Spring Love)
# 봄 (feat. 산다라박)
# 봄날
# 너란 봄 (Feat. 하림)
# 봄날의 기억
# 벚꽃 엔딩
# 봄 사랑 벚꽃 말고
# 나만, 봄
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 우연히 봄
# 봄봄봄
# 너란 봄 (Feat. 하림)
# 봄이 좋냐??
# 봄 사이, 우리 (Prod. by 박근태)
# 완벽한 봄날 (Feat. 소심한 오빠들)
# 걷자, 집앞이야 (Feat. 주예인)
# 사랑일까?
# 너와 나
# 한번더
# 봄이왔다
# 넌 나 어때
# 꽃송이가
# 처음엔 사랑이란게
# 다시 또 봄
# 봄봄봄
# BLUE
# 벚꽃 엔딩
# 봄날, 벚꽃 그리고 너
# 겨울이 지나고 봄이 오듯이
# 봄바람
# 봄 사랑 벚꽃 말고
# 봄
# 꿈만 같아서
# 인형의 꿈
# 살금살금 (Vocal. 김소영)
# 좋아 좋아
# 10시40분 (Vocal. 김소영)
# 봄처녀
# 우리가 연인이 되면 어떤 모습일까? (Feat.이건율)
# Everyday (Feat. 박현일)
# 남자친구 (Feat. 조순균)
# Be There
# Number 1
# 이렇게 좋아해 본 적이 없어요
# 소풍 (Intro)
# 좋아요~ (CF - 농협)
# 숱한 밤들
# Beautiful Day
# Departure
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# Spring I Love You Best
# 봄봄봄
# 1997 Spring
# 봄이 와 (Feat. 롤러코스터)
# 봄이 오면 (Piano ver.)
# 봄이왔다
# 봄날, 벚꽃 그리고 너
# 벚꽃 엔딩
# 봄이 오는 동안
# 꽃 처럼 한 철만 사랑해 줄 건가요?
# I Believe
# 처음 만든 사랑 노래
# 그대와 나, 설레임 (Feat. 소울맨)
# 러브 레시피
# Falling
# People
# 벚꽃 엔딩
# 외로움증폭장치 (브래드 드럼 한판 쉬기)
# 꽃피는 봄이오면
# 봄날 (One Fine Spring Day)
# 봄이 오면
# 봄비 내리면
# 봄
# 따뜻한 봄 햇살 (Feat. 한설희)
# 봄봄봄
# 봄의기적
# 봄의 언어
# 봄
# 잠이솔솔
# 꽃송이가
# Bundle Of Joy
# Sunshine
# 치르치르
# 말하고 싶은 게 있어
# 오후의 행진곡
# 봄바람
# 24
# 너와나의
# 그저 그런 오후
# 29살의 봄
# 그때, 우리로
# 힘내
# 집으로
# 가끔 미치도록 네가 안고 싶어질 때가 있어
# 굿바이
# 여의도 (With 안다영)
# 행복해 (Feat. 타루)
# 하루 끝
# 춤춘다 (Reprise)
# 먼저할래 (Feat. 앤덥)
# 다른 별 (Feat. Lovey)
# 1초 만에 만나는 방법
# 키세스해줘♡
# 봄
# 행복한 나를
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15020/1477448112.py in <module>
#      25             btn = driver.find_elements_by_class_name("thumb_frame")[j]
#      26             btn.click()
# ---> 27             songCount_Xpath = driver.find_element_by_xpath('//*[@id="conts"]/div[4]/div[1]/h5/span')
#      28             songCount = int(songCount_Xpath.text[1:-1])
#      29             for k in range(1,10):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# --> 521         return self.find_element(by=By.XPATH, value=xpath)
#     522
#     523     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1246             value = '[name="%s"]' % value
#    1247
# -> 1248         return self.execute(Command.FIND_ELEMENT, {
#    1249             'using': by,
#    1250             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="conts"]/div[4]/div[1]/h5/span"}
#   (Session info: chrome=102.0.5005.115)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00B9D953+2414931]
# 	Ordinal0 [0x00B2F5E1+1963489]
# 	Ordinal0 [0x00A1C6B8+837304]
# 	Ordinal0 [0x00A49500+1021184]
# 	Ordinal0 [0x00A4979B+1021851]
# 	Ordinal0 [0x00A76502+1205506]
# 	Ordinal0 [0x00A644E4+1131748]
# 	Ordinal0 [0x00A74812+1198098]
# 	Ordinal0 [0x00A642B6+1131190]
# 	Ordinal0 [0x00A3E860+976992]
# 	Ordinal0 [0x00A3F756+980822]
# 	GetHandleVerifier [0x00E0CC62+2510274]
# 	GetHandleVerifier [0x00DFF760+2455744]
# 	GetHandleVerifier [0x00C2EABA+551962]
# 	GetHandleVerifier [0x00C2D916+547446]
# 	Ordinal0 [0x00B35F3B+1990459]
# 	Ordinal0 [0x00B3A898+2009240]
# 	Ordinal0 [0x00B3A985+2009477]
# 	Ordinal0 [0x00B43AD1+2046673]
# 	BaseThreadInitThunk [0x7722FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77557A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77557A6E+238]

# %%
result ={}
musicList = []

# %%
result2 = {"봄":["봄","과","관","련","된","노","래"]}

# %%
result.update(result2)

# %%
base_url = 'https://www.melon.com/search/dj/index.htm?q=%EA%B5%B0%EB%8C%80&section=&searchGnbYn=Y&kkoSpl=Y&kkoDpType=&mwkLogType=T#params%5Bq%5D=%25EA%25B5%25B0%25EB%258C%2580&params%5Bsort%5D=weight&params%5Bsection%5D=all&po=pageObj&startIndex={}'
driver = wb.Chrome()

for n in range(100) :

# %%
for k in range(1,51):
    song_Xpath = driver.find_element_by_xpath('//*[@id="frm"]/div/table/tbody/tr['+str(k)+']/td[5]/div/div/div[1]/span/a')   
    song = song_Xpath.text
    print(song)    
           
 # 곡명을 긁어오는 코드
